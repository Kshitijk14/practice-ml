# %% [markdown]
# # Melbourne House Price Dataset, predict House Prices based on various features.
#
# Dataset:
# https://www.kaggle.com/anthonypino/melbourne-housing-market

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
df = pd.read_csv('Melbourne_housing_FULL.csv')
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# ## Data Analysis & Preprocessing

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# dropping unnecessary cols

# %%
df.drop(['Address', 'Date', 'Postcode', 'YearBuilt', 'Lattitude', 'Longtitude',], axis='columns', inplace=True)
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %% [markdown]
# handling 'NaN' values

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
cols_to_fill_zero = ['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Propertycount']
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)

df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# df['Price'] = df['Price'].fillna(df.Price.median())

df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         3
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
df.dropna(inplace=True)

df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# 5      Abbotsford      3    h   850000.0     PI         Biggin       2.5
# 6      Abbotsford      4    h  1600000.0     VB         Nelson       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %% [markdown]
# OneHotEncoding / DummyVars for the categorical features

# %%
df = pd.get_dummies(df, drop_first=True)
df = df.astype(float)
df
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1        2.0  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2        2.0  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 4        3.0  1465000.0       2.5       3.0       2.0  0.0  134.000000
# 5        3.0   850000.0       2.5       3.0       2.0  1.0   94.000000
# 6        4.0  1600000.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852    4.0  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853    2.0   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854    2.0   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855    3.0  1140000.0       6.3       0.0       0.0  0.0  593.598993
# 34856    2.0  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# ...

# %% [markdown]
# ## Model

# %%
X = df.drop('Price', axis='columns')
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_reg.score(X_test, y_test)
# Out:
# 0.5107699935583883

# %%
linear_reg.score(X_train, y_train)
# Out:
# 0.6872496733784805

# %% [markdown]
# **training score is 68.72% but test score is 51.07% which is very low** --> Normal Regression is clearly over-fitting the data

# %% [markdown]
# ### Using Lasso (L1 Regularized) Regression Model

# %%
lasso_reg = Lasso(alpha=0.1, max_iter=100, tol=0.1)
lasso_reg.fit(X_train, y_train)
# Out:
# c:\Users\Hp\Documents\GitHub\practice-ml\env\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.407e+15, tolerance: 8.993e+14
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1, max_iter=100, tol=0.1)

# %%
lasso_reg.score(X_test, y_test)
# Out:
# 0.5103018631292232

# %%
lasso_reg.score(X_train, y_train)
# Out:
# 0.6871670904882814

# %% [markdown]
# ### Using Ridge (L2 Regularized) Regression Model

# %%
ridge_reg = Ridge(alpha=1, max_iter=100, tol=0.1)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, max_iter=100, tol=0.1)

# %%
ridge_reg.score(X_test, y_test)
# Out:
# 0.5110893034171372

# %%
ridge_reg.score(X_train, y_train)
# Out:
# 0.6867174923755653
